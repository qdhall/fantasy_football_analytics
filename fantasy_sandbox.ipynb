# %%
from espn_api.football import League
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine
# Out:
# /Users/qhall/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
league = League(league_id=23224200, year=2024, espn_s2='AEAeJkkoTaooG%2BUU5zr3ccb3p7rMEYzp2QPA%2F2Vh2dIO9EMvlN8xNqbuVSXa37QQiUn%2BrY9M5vIBwz94BNbJBNOERwRGpXaqo1013tLZCyBoYzvX1X1C%2BpDRtfXzgEyWSPe1ck1bRcEgF0XEKse%2BNKO7bAAgyz7Q7Z2dggtY16%2F3S5MbftgGoQ08brZh0G4z4FvEPc%2BGzUzDLEYS8lEX8CLIrUYDQkP%2FL0m%2F0k%2F7WxfThtbJ42blZENQsVMhJcUvewcMaOofh49SP3bNhnIXAqzDdt8l4RSbOGycrqu95c9YzibQRwKX%2FsyWpd5WR1%2BkHRQ%3D', swid='{1CE75B65-F3E4-4903-A75B-65F3E4E903A7}')

# %%
league.teams

# %%
#Build Teams

teams = []
for team in league.teams:
    teams.append(vars(team))
    
df = pd.DataFrame(teams)
df

# %%
#Build Players On Team
players = []
for team in league.teams:
    for player in team.roster:
        print(player)

# %%
#Build Free Agents
players = []
league._fetch_teams()

# %%
#Head to Head Records
def get_head_to_head_record(team1, team2, week):
    """Calculate head-to-head record between two teams up to a given week"""
    team1_wins = 0
    team2_wins = 0
    
    for w in range(week):
        if team1.schedule[w] == team2:
            if team1.outcomes[w] == 'W':
                team1_wins += 1
            elif team1.outcomes[w] == 'L':
                team2_wins += 1
    
    return f"{team1.team_name}: {team1_wins}-{team2_wins} vs {team2.team_name}"

# %%
# Usage

for year in league.previousSeasons:
    league = League(league_id=23224200, year=year, espn_s2='AEAeJkkoTaooG%2BUU5zr3ccb3p7rMEYzp2QPA%2F2Vh2dIO9EMvlN8xNqbuVSXa37QQiUn%2BrY9M5vIBwz94BNbJBNOERwRGpXaqo1013tLZCyBoYzvX1X1C%2BpDRtfXzgEyWSPe1ck1bRcEgF0XEKse%2BNKO7bAAgyz7Q7Z2dggtY16%2F3S5MbftgGoQ08brZh0G4z4FvEPc%2BGzUzDLEYS8lEX8CLIrUYDQkP%2FL0m%2F0k%2F7WxfThtbJ42blZENQsVMhJcUvewcMaOofh49SP3bNhnIXAqzDdt8l4RSbOGycrqu95c9YzibQRwKX%2FsyWpd5WR1%2BkHRQ%3D', swid='{1CE75B65-F3E4-4903-A75B-65F3E4E903A7}')
    season_length = len(league.teams[0].schedule)
    for week in range(season_length):
        print(year)
        print(week)
#h2h_record = get_head_to_head_record(league.teams[0], league.teams[1], 10)
#h2h_record
# Out:
# 2019
# 0
# 2019
# 1
# 2019
# 2
# 2019
# 3
# 2019
# 4
# 2019
# 5
# 2019
# 6
# 2019
# 7
# 2019
# 8
# 2019
# 9
# 2019
# 10
# 2019
# 11
# 2019
# 12
# 2019
# 13
# 2019
# 14
# 2019
# 15
# 2020
# 0
# 2020
# 1
# 2020
# 2
# 2020
# 3
# 2020
# 4
# 2020
# 5
# 2020
# 6
# 2020
# 7
# 2020
# 8
# 2020
# 9
# 2020
# 10
# 2020
# 11
# 2020
# 12
# 2020
# 13
# 2020
# 14
# 2020
# 15
# 2021
# 0
# 2021
# 1
# 2021
# 2
# 2021
# 3
# 2021
# 4
# 2021
# 5
# 2021
# 6
# 2021
# 7
# 2021
# 8
# 2021
# 9
# 2021
# 10
# 2021
# 11
# 2021
# 12
# 2021
# 13
# 2021
# 14
# 2021
# 15
# 2021
# 16
# 2022
# 0
# 2022
# 1
# 2022
# 2
# 2022
# 3
# 2022
# 4
# 2022
# 5
# 2022
# 6
# 2022
# 7
# 2022
# 8
# 2022
# 9
# 2022
# 10
# 2022
# 11
# 2022
# 12
# 2022
# 13
# 2022
# 14
# 2022
# 15
# 2022
# 16
# 2023
# 0
# 2023
# 1
# 2023
# 2
# 2023
# 3
# 2023
# 4
# 2023
# 5
# 2023
# 6
# 2023
# 7
# 2023
# 8
# 2023
# 9
# 2023
# 10
# 2023
# 11
# 2023
# 12
# 2023
# 13
# 2023
# 14
# 2023
# 15
# 2023
# 16

# %%
def get_teams(league_id, start_year, end_year, espn_s2=None, swid=None):
    """Calculate all-time head-to-head records across multiple seasons"""
    
    # Dictionary to store all-time records: {(team1_id, team2_id): {'team1_wins': X, 'team2_wins': Y}}
    all_time_h2h = {}
    
    # Track team names across years (team IDs might stay the same, names might change)
    team_names = {}
    
    for year in range(start_year, end_year + 1):
        print(f"Processing {year} season...")
        
        try:
            league = League(league_id, year, espn_s2=espn_s2, swid=swid)
            
            # Update team names for this year
            for team in league.teams:
                team_names[team.team_id] = team.team_name
            print(f"Season {team_names}:")
            print(team_names)

        except Exception as e:
            print(f"Error processing {year}: {e}")

# %%
teams = get_teams(
    league_id=23224200,
    start_year=2019,
    end_year=2024,
    espn_s2='AEAeJkkoTaooG%2BUU5zr3ccb3p7rMEYzp2QPA%2F2Vh2dIO9EMvlN8xNqbuVSXa37QQiUn%2BrY9M5vIBwz94BNbJBNOERwRGpXaqo1013tLZCyBoYzvX1X1C%2BpDRtfXzgEyWSPe1ck1bRcEgF0XEKse%2BNKO7bAAgyz7Q7Z2dggtY16%2F3S5MbftgGoQ08brZh0G4z4FvEPc%2BGzUzDLEYS8lEX8CLIrUYDQkP%2FL0m%2F0k%2F7WxfThtbJ42blZENQsVMhJcUvewcMaOofh49SP3bNhnIXAqzDdt8l4RSbOGycrqu95c9YzibQRwKX%2FsyWpd5WR1%2BkHRQ%3D', 
    swid='{1CE75B65-F3E4-4903-A75B-65F3E4E903A7}'
)
teams
# Out:
# Processing 2019 season...
# Season {1: 'Dressed TuaT', 2: 'Black Don’t Crack', 3: 'Team Dobbs', 4: 'Brees 4 MVP', 5: 'chillin with mahomies', 6: 'Happy Golladays', 7: 'In Todd We Trust', 8: 'Team Raymond', 9: 'Zeke Ya Later Steen', 10: 'Team Miller', 11: 'Team Barnes', 12: 'Jim Lahey’s ShitHawks'}:
# {1: 'Dressed TuaT', 2: 'Black Don’t Crack', 3: 'Team Dobbs', 4: 'Brees 4 MVP', 5: 'chillin with mahomies', 6: 'Happy Golladays', 7: 'In Todd We Trust', 8: 'Team Raymond', 9: 'Zeke Ya Later Steen', 10: 'Team Miller', 11: 'Team Barnes', 12: 'Jim Lahey’s ShitHawks'}
# Processing 2020 season...
# Season {1: 'Surtainly Good.... NOT', 2: 'Black Don’t Crack', 3: 'Muscle Shoals  Beavers', 4: "Odell's  ACL", 5: 'Behind the 8-Ball', 6: 'COVID DEEZ', 7: 'Call of Jeudy', 8: 'Team Raymond', 9: "Steen's Abiders (Scenes)", 10: 'Washington Fantasy Team', 11: 'Team Barnes', 12: 'Jim Lahey’s ShitHawks'}:
# {1: 'Surtainly Good.... NOT', 2: 'Black Don’t Crack', 3: 'Muscle Shoals  Beavers', 4: "Odell's  ACL", 5: 'Behind the 8-Ball', 6: 'COVID DEEZ', 7: 'Call of Jeudy', 8: 'Team Raymond', 9: "Steen's Abiders (Scenes)", 10: 'Washington Fantasy Team', 11: 'Team Barnes', 12: 'Jim Lahey’s ShitHawks'}
# Processing 2021 season...
# Season {1: 'Team E.E.E.', 2: 'Black King ', 3: 'YeahUhhIm ThinkingMeLikey', 4: 'Griddy 4 Gold', 5: 'Kyler, The Creator', 6: 'La  Beast', 7: 'The Real Slim Brady', 8: "Show me your TD's", 9: 'CeeDeez Nuts CD', 10: 'Washington Fantasy Team', 11: 'Lou Sassle', 12: 'Jim Lahey’s ShitHawks'}:
# {1: 'Team E.E.E.', 2: 'Black King ', 3: 'YeahUhhIm ThinkingMeLikey', 4: 'Griddy 4 Gold', 5: 'Kyler, The Creator', 6: 'La  Beast', 7: 'The Real Slim Brady', 8: "Show me your TD's", 9: 'CeeDeez Nuts CD', 10: 'Washington Fantasy Team', 11: 'Lou Sassle', 12: 'Jim Lahey’s ShitHawks'}
# Processing 2022 season...
# Season {1: 'Zynner Time', 2: 'No Losses, Only Lessons ', 3: 'YeahUhhIm ThinkingMeLikey', 4: 'Abider of  TLaw ', 5: 'Obi-Wan Mahomie', 6: 'The Jeffersons', 7: 'Rashodies B Trippin', 8: 'Big Beudy Jeudy', 9: 'Zeke and Destroy', 10: 'Team Bishop', 11: 'TwoGirls OneKupp', 12: 'Jim Lahey’s ShitHawks'}:
# {1: 'Zynner Time', 2: 'No Losses, Only Lessons ', 3: 'YeahUhhIm ThinkingMeLikey', 4: 'Abider of  TLaw ', 5: 'Obi-Wan Mahomie', 6: 'The Jeffersons', 7: 'Rashodies B Trippin', 8: 'Big Beudy Jeudy', 9: 'Zeke and Destroy', 10: 'Team Bishop', 11: 'TwoGirls OneKupp', 12: 'Jim Lahey’s ShitHawks'}
# Processing 2023 season...
# Season {1: 'Zynner Time', 2: 'Q-Tip', 3: 'YeahUhhIm ThinkingMeLikey', 4: 'Abider of  TLaw ', 5: 'The Coconut Cornhuskies', 6: 'Tig ole Griddys', 7: 'Off In Church', 8: 'Bryce Bryce Baby', 9: 'Zeke and Destroy', 10: 'Boats and Younghoes', 11: "Balboni's Bad Boyz", 12: 'Can you Diggs it? '}:
# {1: 'Zynner Time', 2: 'Q-Tip', 3: 'YeahUhhIm ThinkingMeLikey', 4: 'Abider of  TLaw ', 5: 'The Coconut Cornhuskies', 6: 'Tig ole Griddys', 7: 'Off In Church', 8: 'Bryce Bryce Baby', 9: 'Zeke and Destroy', 10: 'Boats and Younghoes', 11: "Balboni's Bad Boyz", 12: 'Can you Diggs it? '}
# Processing 2024 season...
# Season {1: 'Zynner Time', 2: 'Take Over Yo Trap', 3: 'YeahUhhIm ThinkingMeLikey', 4: 'We Are Hawk Tuah', 5: 'Brocked Up', 6: 'Tig ole Griddys', 7: 'Off In Church', 8: 'Run CMC', 9: 'Bowles is a Moron', 10: 'Lost in the Moss', 11: 'Boom Bringer', 12: 'White Dudes for Harrison '}:
# {1: 'Zynner Time', 2: 'Take Over Yo Trap', 3: 'YeahUhhIm ThinkingMeLikey', 4: 'We Are Hawk Tuah', 5: 'Brocked Up', 6: 'Tig ole Griddys', 7: 'Off In Church', 8: 'Run CMC', 9: 'Bowles is a Moron', 10: 'Lost in the Moss', 11: 'Boom Bringer', 12: 'White Dudes for Harrison '}

# %%
league.
# Out:
# 17

# %%
def get_all_time_h2h_by_scores_fixed(league_id, start_year, end_year, espn_s2=None, swid=None):
    """Fixed version - correctly award wins to the team with the HIGHER score"""
    
    all_time_h2h = {}
    team_names = {}
    
    for year in range(start_year, end_year + 1):
        print(f"Processing {year} season...")
        
        try:
            league = League(league_id, year, espn_s2=espn_s2, swid=swid)
            
            for team in league.teams:
                team_names[team.team_id] = team.team_name
            
            max_week = league.current_week
            processed_games = set()
            
            for week in range(max_week):
                for team in league.teams:
                    if (week < len(team.schedule) and 
                        week < len(team.scores) and 
                        hasattr(team.schedule[week], 'team_id')):
                        
                        opponent = team.schedule[week]
                        team_score = team.scores[week]
                        opponent_score = opponent.scores[week]
                        
                        # Skip if no scores available
                        if team_score is None or opponent_score is None:
                            continue
                        
                        # Avoid double counting
                        game_id = tuple(sorted([team.team_id, opponent.team_id]))
                        full_game_id = (year, week, *game_id)
                        
                        if full_game_id in processed_games:
                            continue
                        processed_games.add(full_game_id)
                        
                        # FIX: Correctly determine winner by HIGHER score
                        if team_score > opponent_score:
                            # Team won (higher score)
                            winner_id = team.team_id
                            winner_name = team.team_name
                            loser_id = opponent.team_id
                            loser_name = opponent.team_name
                        elif opponent_score > team_score:
                            # Opponent won (higher score)
                            winner_id = opponent.team_id
                            winner_name = opponent.team_name
                            loser_id = team.team_id
                            loser_name = team.team_name
                        else:
                            continue  # Skip ties
                        
                        # Create consistent key (always smaller ID first for consistency)
                        key = tuple(sorted([team.team_id, opponent.team_id]))
                        
                        if key not in all_time_h2h:
                            all_time_h2h[key] = {team.team_id: 0, opponent.team_id: 0}
                        
                        # CRITICAL FIX: Record the win for the team with HIGHER score
                        all_time_h2h[key][winner_id] += 1
                        
                        # Debug print for first few games
                        #if len(processed_games) <= 3:
                           # print(f"  Game: {winner_name} ({team_score if winner_id == team.team_id else opponent_score}) beat {loser_name} ({opponent_score if winner_id == team.team_id else team_score})")
                           # print(f"    Recording win for {winner_name} (ID: {winner_id})")
        
        except Exception as e:
            print(f"Error processing {year}: {e}")
    
    # Convert to readable format
    readable_records = {}
    for (team1_id, team2_id), wins_dict in all_time_h2h.items():
        team1_name = team_names.get(team1_id, f"Team {team1_id}")
        team2_name = team_names.get(team2_id, f"Team {team2_id}")
        
        team1_wins = wins_dict.get(team1_id, 0)
        team2_wins = wins_dict.get(team2_id, 0)
        
        # Create both directions for easy lookup
        key1 = f"{team1_name} vs {team2_name}"
        key2 = f"{team2_name} vs {team1_name}"
        
        readable_records[key1] = {
            'team1': team1_name,
            'team1_wins': team1_wins,
            'team2': team2_name,
            'team2_wins': team2_wins,
            'total_games': team1_wins + team2_wins
        }
        
        readable_records[key2] = {
            'team1': team2_name,
            'team1_wins': team2_wins,
            'team2': team1_name,
            'team2_wins': team1_wins,
            'total_games': team1_wins + team2_wins
        }
    
    return readable_records

# %%
# Usage
h2h_records = get_all_time_head_to_head(
    league_id=23224200,
    start_year=2024,
    end_year=2024,
    espn_s2='AEAeJkkoTaooG%2BUU5zr3ccb3p7rMEYzp2QPA%2F2Vh2dIO9EMvlN8xNqbuVSXa37QQiUn%2BrY9M5vIBwz94BNbJBNOERwRGpXaqo1013tLZCyBoYzvX1X1C%2BpDRtfXzgEyWSPe1ck1bRcEgF0XEKse%2BNKO7bAAgyz7Q7Z2dggtY16%2F3S5MbftgGoQ08brZh0G4z4FvEPc%2BGzUzDLEYS8lEX8CLIrUYDQkP%2FL0m%2F0k%2F7WxfThtbJ42blZENQsVMhJcUvewcMaOofh49SP3bNhnIXAqzDdt8l4RSbOGycrqu95c9YzibQRwKX%2FsyWpd5WR1%2BkHRQ%3D', 
    swid='{1CE75B65-F3E4-4903-A75B-65F3E4E903A7}'
)

 #Print results
for matchup, record in h2h_records.items():
    print(h2h_records)

# %%
def create_h2h_matrix(league_id, start_year, end_year, espn_s2=None, swid=None):
    """Cheat fix - just flip the wins and losses in the display"""
    
    import pandas as pd
    
    # Get records using the scores function
    all_records = get_all_time_h2h_by_scores_fixed(league_id, start_year, end_year, espn_s2, swid)
    
    # Extract team names
    all_teams = set()
    for key in all_records.keys():
        if " vs " in key:
            teams = key.split(" vs ")
            if len(teams) == 2:
                all_teams.add(teams[0])
                all_teams.add(teams[1])
    
    all_teams = sorted(list(all_teams))
    
    # Create matrix
    matrix_data = {}
    for row_team in all_teams:
        matrix_data[row_team] = {}
        for col_team in all_teams:
            if row_team == col_team:
                matrix_data[row_team][col_team] = "-"
            else:
                lookup_key = f"{row_team} vs {col_team}"
                
                if lookup_key in all_records:
                    record = all_records[lookup_key]
                    
                    # CHEAT: Just flip the wins and losses
                    flipped_wins = record['team2_wins']  # Use team2's wins as row team's wins
                    flipped_losses = record['team1_wins']  # Use team1's wins as row team's losses
                    
                    matrix_data[row_team][col_team] = f"{flipped_wins}-{flipped_losses}"
                else:
                    matrix_data[row_team][col_team] = "0-0"
    
    df = pd.DataFrame(matrix_data)
    return df

# %%
# Usage
matrix = create_h2h_matrix(league_id=23224200,
    start_year=2019,
    end_year=2025,
    espn_s2='AEAeJkkoTaooG%2BUU5zr3ccb3p7rMEYzp2QPA%2F2Vh2dIO9EMvlN8xNqbuVSXa37QQiUn%2BrY9M5vIBwz94BNbJBNOERwRGpXaqo1013tLZCyBoYzvX1X1C%2BpDRtfXzgEyWSPe1ck1bRcEgF0XEKse%2BNKO7bAAgyz7Q7Z2dggtY16%2F3S5MbftgGoQ08brZh0G4z4FvEPc%2BGzUzDLEYS8lEX8CLIrUYDQkP%2FL0m%2F0k%2F7WxfThtbJ42blZENQsVMhJcUvewcMaOofh49SP3bNhnIXAqzDdt8l4RSbOGycrqu95c9YzibQRwKX%2FsyWpd5WR1%2BkHRQ%3D', 
    swid='{1CE75B65-F3E4-4903-A75B-65F3E4E903A7}')
print()
print("Athletic Enough to Play Fantasy Football Head-To-Head Matrix")
print()
matrix
# Out:
# Processing 2019 season...
# Processing 2020 season...
# Processing 2021 season...
# Processing 2022 season...
# Processing 2023 season...
# Processing 2024 season...
# Processing 2025 season...
#
# Athletic Enough to Play Fantasy Football Head-To-Head Matrix
#                   Big Gibbies Boom Bringer Bowles is a Moron CeeDee's Nuts  \
# Big Gibbies                 -          2-7               5-7           6-5
# Boom Bringer              7-2            -               9-4           7-4
# Bowles is a Moron         7-5          4-9                 -           5-6
# CeeDee's Nuts             5-6          4-7               6-5             -
# Hunter Travis             4-4          3-5               4-4           2-4
# Off In Church             3-7          0-7               7-5           6-3
# Take Over Yo Trap         8-3          4-3               4-3           5-2
# Tate Malone               6-1          7-3               5-1           4-4
# The Hard Hogs             4-3          5-1               4-3           5-1
# Tig ole Griddys           3-4          4-4               5-3           4-4
# Ward of the Wings         5-5          4-3               3-5           6-6
# Zynner Time               5-2          8-5               5-3          1-10
#
#                   Hunter Travis  Off In Church Take Over Yo Trap Tate Malone  \
# Big Gibbies                  4-4           7-3               3-8         1-6
# Boom Bringer                 5-3           7-0               3-4         3-7
# Bowles is a Moron            4-4           5-7               3-4         1-5
# CeeDee's Nuts                4-2           3-6               2-5         4-4
# Hunter Travis                  -           3-4              10-4         6-6
# Off In Church                4-3             -               3-7         4-7
# Take Over Yo Trap           4-10           7-3                 -         3-3
# Tate Malone                  6-6           7-4               3-3           -
# The Hard Hogs                6-2           2-5               5-5         9-3
# Tig ole Griddys              7-4           5-3               3-4         6-1
# Ward of the Wings            2-5           2-5               4-8         3-9
# Zynner Time                  4-5           5-6               7-1         5-2
#
#                   The Hard Hogs Tig ole Griddys Ward of the Wings Zynner Time
# Big Gibbies                 3-4             4-3               5-5         2-5
# Boom Bringer                1-5             4-4               3-4         5-8
# Bowles is a Moron           3-4             3-5               5-3         3-5
# CeeDee's Nuts               1-5             4-4               6-6        10-1
# Hunter Travis               2-6             4-7               5-2         5-4
# Off In Church               5-2             3-5               5-2         6-5
# Take Over Yo Trap           5-5             4-3               8-4         1-7
# Tate Malone                 3-9             1-6               9-3         2-5
# The Hard Hogs                 -            6-10               7-1         4-6
# Tig ole Griddys            10-6               -               5-6         3-6
# Ward of the Wings           1-7             6-5                 -         3-3
# Zynner Time                 6-4             6-3               3-3           -

# %%
league.teams[0].
# Out:
# [Team(Bowles is a Moron),
#  Team(Run CMC),
#  Team(Take Over Yo Trap),
#  Team(Tig ole Griddys),
#  Team(White Dudes for Harrison ),
#  Team(Brocked Up),
#  Team(Off In Church),
#  Team(Boom Bringer),
#  Team(Lost in the Moss),
#  Team(YeahUhhIm ThinkingMeLikey),
#  Team(We Are Hawk Tuah),
#  Team(Brocked Up),
#  Team(Off In Church),
#  Team(Boom Bringer),
#  Team(Lost in the Moss),
#  Team(White Dudes for Harrison ),
#  Team(Tig ole Griddys)]

# %%
engine = create_engine('mysql+mysqlconnector://root:epitoG6!399tyJQ@localhost:3306/fantasy_football', echo=False)
df.to_sql(name='teams', con=engine, if_exists = 'replace', index=False)

# %%
league.teams[5].division_name

# %%
divisions = { 'division_id': ['0', '1'],
              'division_name': ['East', 'West']
        }
divisions_df = pd.DataFrame(divisions)
divisions_df.to_sql(name='divisions', con=engine, if_exists = 'replace', index=False)

# %%
league.power_rankings(week=13)

# %%
scoreboard = league.scoreboard(week=12)
scoreboard

# %%
matchup = scoreboard[1]
matchup._fetch_matchup_info

# %%
#Against the Spread
home_projections = 0
home_points = 0
home_starting_lineup = {'QB': 'Josh Allen',
                        'RB1': 'Kyren Williams',
                        'RB2': 'Rhamondre Stevenson',
                        'WR1': 'Ja\'Marr Chase',
                        'WR2': 'Malik Nabers',
                        'TE': 'Brock Bowers',
                        'FLEX': 'Tony Pollard',
                        'D/ST': 'Browns D/ST',
                        'K': 'Cameron Dicker'}


for player in box_scores[0].home_lineup:
    if player.name in home_starting_lineup.values():
        home_projections += player.projected_points
        home_points += player.points


away_projections = 0
away_points = 0
away_starting_lineup = {'QB': 'Lamar Jackson',
                        'RB1': 'Rachaad White',
                        'RB2': 'Javonte Williams',
                        'WR1': 'Tyreek Hill',
                        'WR2': 'Mike Evans',
                        'TE': 'Jake Ferguson',
                        'FLEX': 'Tank Dell',
                        'D/ST': 'Saints D/ST',
                        'K': 'Justin Tucker'}


for player in box_scores[0].away_lineup:
    if player.name in away_starting_lineup.values():
        away_projections += player.projected_points
        away_points += player.points

spread = max(home_projections, away_projections) - min(home_projections, away_projections)

favored = ''
if home_projections > away_projections:
    favored = box_scores[0].home_team
else:
    favored = box_scores[0].away_team

dif = max(home_points, away_points) - min(home_points, away_points)
winner = ''
if home_points > away_points:
    winner = box_scores[0].home_team
    loser = box_scores[0].away_team
else:
    winner = box_scores[0].away_team
    loser = box_scores[0].home_team

covered = ''
if winner.team_name == favored.team_name:
    if dif >= spread:
        covered = winner
    else:
        covered = loser
else:
    covered = loser
    
print(f"Home Projected: {home_projections} Away Projected: {away_projections}")
print(f"Home Points: {home_points} Away Points: {away_points}")
print(f"Spread: {favored.team_name} (-{spread})")
print(f"Covered: {covered.team_name}")

# %%
#Least Scored Week All Time
league.least_scored_week()

# %%
#Top Scored Week
league.top_scorer()

# %%
#Top Score All Time
league.top_scored_week()

# %%
#Least Scored Week
league.least_scorer()

# %%
#Least Scored Week
league.least_scored_week()

# %%
#Overall Standings
league.standings()
